# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %% [markdown]
# ### Dataset caching
# Since we are using only the small 32x32 versions of the images I can fit the entire dataset in under 100MB of the GPU memory rather than reading the high res image from the disk and scaling it down each time. This speeded up my training by around 30%

# %%
class CacheTensorDataset(torch.utils.data.dataset.Dataset):
    def __init__(self, ds):
        self.data = []
        for t in ds:
            if torch.cuda.is_available():
                t = (t[0].cuda(), t[1])
            self.data.append(t)
    def __getitem__(self, index):
        return self.data[index]
    def __len__(self):
        return len(self.data)

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    tfms = transforms.Compose([
        transforms.Resize(image_size),
        transforms.CenterCrop(image_size),
        transforms.ToTensor()
    ])
    dataset = datasets.ImageFolder(data_dir, transform = tfms)
    cached = CacheTensorDataset(dataset)
    dataloader = torch.utils.data.DataLoader(cached, batch_size, shuffle = True)
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 512
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.cpu().numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    mn, mx = feature_range
    return x * (mx - mn) + mn

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.8667)
# Max:  tensor(0.9451)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size = 4, stride = 2, padding = 1):
        super(ConvBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.bn = nn.BatchNorm2d(out_channels)
    def forward(self, x):
        return F.leaky_relu(self.bn(self.conv(x)))

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        self.convs = nn.Sequential(
            ConvBlock(3, conv_dim),
            ConvBlock(conv_dim, conv_dim * 2),
            ConvBlock(conv_dim * 2, conv_dim * 4),
            ConvBlock(conv_dim * 4, conv_dim * 8)
        )
        
        self.classifier = nn.Linear(conv_dim * 8, 1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        x = self.convs(x)
        x = F.adaptive_max_pool2d(x, 1).view(x.shape[0], -1)
        return self.classifier(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class DeConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size = 4, stride = 2, padding = 1, activate = True):
        super(DeConvBlock, self).__init__()
        self.conv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding)
        self.bn = nn.BatchNorm2d(out_channels)
        self.activate = activate
    def forward(self, x):
        x = self.bn(self.conv(x))
        if self.activate:
            x = F.leaky_relu(x)
        return x

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        self.initial = nn.Linear(z_size, 2 * 2 * conv_dim * 8) # 2x2 image with conv_dim * 8 channels
        self.initial_bm = nn.BatchNorm1d(2 * 2 * conv_dim * 8)
        self.convs = nn.Sequential(
            DeConvBlock(conv_dim * 8, conv_dim * 4),
            DeConvBlock(conv_dim * 4, conv_dim * 2),
            DeConvBlock(conv_dim * 2, conv_dim),
            DeConvBlock(conv_dim, 3, activate = False)
        )
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        x = F.leaky_relu(self.initial_bm(self.initial(x)))
        x = x.view(x.shape[0], -1, 2, 2)
        x = self.convs(x)
        return torch.tanh(x)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    if classname == 'Conv2d' or classname == 'ConvTranspose2d':
        torch.nn.init.normal_(m.weight.data, 0, 0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32 
z_size = 50

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (convs): Sequential(
#     (0): ConvBlock(
#       (conv): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ConvBlock(
#       (conv): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ConvBlock(
#       (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ConvBlock(
#       (conv): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (classifier): Linear(in_features=256, out_features=1, bias=True)
# )
#
# Generator(
#   (initial): Linear(in_features=50, out_features=1024, bias=True)
#   (initial_bm): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (convs): Sequential(
#     (0): DeConvBlock(
#       (conv): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): DeConvBlock(
#       (conv): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): DeConvBlock(
#       (conv): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): DeConvBlock(
#       (conv): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    labels = torch.ones_like(D_out) * .9
    loss = F.binary_cross_entropy_with_logits(D_out, labels)
    #loss = F.mse_loss(D_out, labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    labels = torch.zeros_like(D_out)
    loss = F.binary_cross_entropy_with_logits(D_out, labels)
    #loss = F.mse_loss(D_out, labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
lr = 0.0002
beta1=0.5
beta2=.999

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr,(beta1, beta2))
g_optimizer = optim.Adam(G.parameters(), lr, (beta1, beta2))

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def get_random_seed(batch_size, z_size):
    '''Random tensor z with shape (batch_size, z_size) to seed the generator'''
    z = torch.empty(batch_size, z_size).uniform_(-1, 1)
    if train_on_gpu:
        z = z.cuda()   
    return z

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            if train_on_gpu:
                real_images = real_images.cuda()
            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            
            # Generate fake images
            d_optimizer.zero_grad()
            z = get_random_seed(batch_size, z_size)
            fake_images = G(z)
            
            # Calculate losses
            #d_loss = torch.tensor(0)
            d_loss = real_loss(D(real_images)) + fake_loss(D(fake_images))
            # Optimizer step
            d_loss.backward()
            d_optimizer.step()
            
            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            # Generate fake images
            z = get_random_seed(batch_size, z_size)
            fake_images = G(z)
            
            # Calculate loss
            g_loss = real_loss(D(fake_images))
            
            # Optimizer step
            g_loss.backward()
            g_optimizer.step()
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# %%time
# set number of epochs 
n_epochs = 100


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/  100] | d_loss: 0.8604 | g_loss: 2.4851
# Epoch [    1/  100] | d_loss: 0.7785 | g_loss: 1.3999
# Epoch [    1/  100] | d_loss: 0.7344 | g_loss: 1.7970
# Epoch [    1/  100] | d_loss: 0.8614 | g_loss: 1.5830
# Epoch [    2/  100] | d_loss: 0.8550 | g_loss: 1.4093
# Epoch [    2/  100] | d_loss: 0.7436 | g_loss: 1.5997
# Epoch [    2/  100] | d_loss: 0.6618 | g_loss: 2.2384
# Epoch [    2/  100] | d_loss: 0.8300 | g_loss: 1.6547
# Epoch [    3/  100] | d_loss: 0.7164 | g_loss: 1.9243
# Epoch [    3/  100] | d_loss: 0.7699 | g_loss: 1.5953
# Epoch [    3/  100] | d_loss: 0.7264 | g_loss: 1.8566
# Epoch [    3/  100] | d_loss: 0.8094 | g_loss: 1.5546
# Epoch [    4/  100] | d_loss: 0.7179 | g_loss: 1.6422
# Epoch [    4/  100] | d_loss: 0.7570 | g_loss: 2.5308
# Epoch [    4/  100] | d_loss: 0.6895 | g_loss: 1.9378
# Epoch [    4/  100] | d_loss: 0.7920 | g_loss: 1.8120
# Epoch [    5/  100] | d_loss: 1.1005 | g_loss: 2.8434
# Epoch [    5/  100] | d_loss: 0.7729 | g_loss: 2.0667
# Epoch [    5/  100] | d_loss: 0.8584 | g_loss: 1.7008
# Epoch [    5/  100] | d_loss: 0.7760 | g_loss: 1.4579
# Epoch [    6/  100] | d_loss: 0.7038 | g_loss: 1.6395
# Epoch [    6/  100] | d_loss: 0.7347 | g_loss: 2.1023
# Epoch [    6/  100] | d_loss: 0.7367 | g_loss: 3.0067
# Epoch [    6/  100] | d_loss: 0.7393 | g_loss: 1.9606
# Epoch [    7/  100] | d_loss: 0.6392 | g_loss: 2.3424
# Epoch [    7/  100] | d_loss: 0.6573 | g_loss: 2.2352
# Epoch [    7/  100] | d_loss: 0.8328 | g_loss: 2.6793
# Epoch [    7/  100] | d_loss: 0.6198 | g_loss: 1.9396
# Epoch [    8/  100] | d_loss: 0.6920 | g_loss: 1.9155
# Epoch [    8/  100] | d_loss: 0.7349 | g_loss: 1.6027
# Epoch [    8/  100] | d_loss: 1.1371 | g_loss: 1.4310
# Epoch [    8/  100] | d_loss: 0.6713 | g_loss: 2.4141
# Epoch [    9/  100] | d_loss: 0.6990 | g_loss: 2.2039
# Epoch [    9/  100] | d_loss: 0.9933 | g_loss: 1.0993
# Epoch [    9/  100] | d_loss: 0.8156 | g_loss: 1.8605
# Epoch [    9/  100] | d_loss: 0.6591 | g_loss: 1.8537
# Epoch [   10/  100] | d_loss: 0.6561 | g_loss: 2.3410
# Epoch [   10/  100] | d_loss: 0.7489 | g_loss: 1.9077
# Epoch [   10/  100] | d_loss: 0.6692 | g_loss: 2.4855
# Epoch [   10/  100] | d_loss: 0.8325 | g_loss: 2.4281
# Epoch [   11/  100] | d_loss: 0.6888 | g_loss: 2.1198
# Epoch [   11/  100] | d_loss: 0.6807 | g_loss: 1.9212
# Epoch [   11/  100] | d_loss: 0.8049 | g_loss: 3.3475
# Epoch [   11/  100] | d_loss: 0.6732 | g_loss: 1.8041
# Epoch [   12/  100] | d_loss: 0.6137 | g_loss: 2.1682
# Epoch [   12/  100] | d_loss: 0.7435 | g_loss: 1.5391
# Epoch [   12/  100] | d_loss: 0.6161 | g_loss: 2.3838
# Epoch [   12/  100] | d_loss: 0.7249 | g_loss: 2.1265
# Epoch [   13/  100] | d_loss: 0.6430 | g_loss: 2.8060
# Epoch [   13/  100] | d_loss: 0.5784 | g_loss: 2.3783
# Epoch [   13/  100] | d_loss: 0.6139 | g_loss: 2.5548
# Epoch [   13/  100] | d_loss: 0.5971 | g_loss: 2.5621
# Epoch [   14/  100] | d_loss: 0.7811 | g_loss: 2.5303
# Epoch [   14/  100] | d_loss: 0.6015 | g_loss: 3.0690
# Epoch [   14/  100] | d_loss: 0.8085 | g_loss: 2.6521
# Epoch [   14/  100] | d_loss: 0.6004 | g_loss: 2.1866
# Epoch [   15/  100] | d_loss: 0.7438 | g_loss: 1.7926
# Epoch [   15/  100] | d_loss: 0.5527 | g_loss: 2.7150
# Epoch [   15/  100] | d_loss: 0.7867 | g_loss: 2.1350
# Epoch [   15/  100] | d_loss: 0.7107 | g_loss: 1.8810
# Epoch [   16/  100] | d_loss: 0.6031 | g_loss: 2.2220
# Epoch [   16/  100] | d_loss: 0.6762 | g_loss: 1.6839
# Epoch [   16/  100] | d_loss: 0.5697 | g_loss: 2.5328
# Epoch [   16/  100] | d_loss: 0.5799 | g_loss: 2.3944
# Epoch [   17/  100] | d_loss: 0.8035 | g_loss: 1.2823
# Epoch [   17/  100] | d_loss: 0.9640 | g_loss: 1.8099
# Epoch [   17/  100] | d_loss: 0.7065 | g_loss: 1.4434
# Epoch [   17/  100] | d_loss: 0.5949 | g_loss: 2.1657
# Epoch [   18/  100] | d_loss: 0.5718 | g_loss: 2.1680
# Epoch [   18/  100] | d_loss: 0.5114 | g_loss: 1.6665
# Epoch [   18/  100] | d_loss: 0.5911 | g_loss: 1.7252
# Epoch [   18/  100] | d_loss: 0.5741 | g_loss: 2.8625
# Epoch [   19/  100] | d_loss: 0.9720 | g_loss: 1.2956
# Epoch [   19/  100] | d_loss: 0.5684 | g_loss: 1.8757
# Epoch [   19/  100] | d_loss: 0.9906 | g_loss: 1.3617
# Epoch [   19/  100] | d_loss: 0.6409 | g_loss: 2.0986
# Epoch [   20/  100] | d_loss: 0.6258 | g_loss: 2.2633
# Epoch [   20/  100] | d_loss: 0.6471 | g_loss: 3.0647
# Epoch [   20/  100] | d_loss: 0.6305 | g_loss: 1.4630
# Epoch [   20/  100] | d_loss: 0.5336 | g_loss: 2.6896
# Epoch [   21/  100] | d_loss: 0.7562 | g_loss: 3.3326
# Epoch [   21/  100] | d_loss: 0.5119 | g_loss: 2.0834
# Epoch [   21/  100] | d_loss: 0.5061 | g_loss: 2.5018
# Epoch [   21/  100] | d_loss: 0.6289 | g_loss: 2.5015
# Epoch [   22/  100] | d_loss: 0.5043 | g_loss: 2.5201
# Epoch [   22/  100] | d_loss: 0.6536 | g_loss: 1.5642
# Epoch [   22/  100] | d_loss: 0.6304 | g_loss: 3.0760
# Epoch [   22/  100] | d_loss: 0.5924 | g_loss: 2.0330
# Epoch [   23/  100] | d_loss: 0.5998 | g_loss: 2.1937
# Epoch [   23/  100] | d_loss: 0.5371 | g_loss: 2.6093
# Epoch [   23/  100] | d_loss: 0.8138 | g_loss: 1.8977
# Epoch [   23/  100] | d_loss: 0.7555 | g_loss: 2.5348
# Epoch [   24/  100] | d_loss: 0.5788 | g_loss: 2.3498
# Epoch [   24/  100] | d_loss: 0.5799 | g_loss: 2.1438
# Epoch [   24/  100] | d_loss: 0.6179 | g_loss: 1.8334
# Epoch [   24/  100] | d_loss: 0.6108 | g_loss: 2.0936
# Epoch [   25/  100] | d_loss: 0.4967 | g_loss: 2.4517
# Epoch [   25/  100] | d_loss: 0.5064 | g_loss: 2.5584
# Epoch [   25/  100] | d_loss: 0.6338 | g_loss: 2.2016
# Epoch [   25/  100] | d_loss: 0.5621 | g_loss: 2.1874
# Epoch [   26/  100] | d_loss: 0.5734 | g_loss: 2.8742
# Epoch [   26/  100] | d_loss: 0.6149 | g_loss: 2.3898
# Epoch [   26/  100] | d_loss: 0.5405 | g_loss: 2.6443
# Epoch [   26/  100] | d_loss: 0.5539 | g_loss: 2.1039
# Epoch [   27/  100] | d_loss: 0.6131 | g_loss: 2.6021
# Epoch [   27/  100] | d_loss: 0.5412 | g_loss: 2.6309
# Epoch [   27/  100] | d_loss: 0.8629 | g_loss: 2.1311
# Epoch [   27/  100] | d_loss: 0.5829 | g_loss: 2.6998
# Epoch [   28/  100] | d_loss: 0.9549 | g_loss: 1.8409
# Epoch [   28/  100] | d_loss: 0.6079 | g_loss: 1.4859
# Epoch [   28/  100] | d_loss: 0.6257 | g_loss: 2.5445
# Epoch [   28/  100] | d_loss: 0.5430 | g_loss: 2.2022
# Epoch [   29/  100] | d_loss: 0.6960 | g_loss: 3.1377
# Epoch [   29/  100] | d_loss: 0.6006 | g_loss: 2.3133
# Epoch [   29/  100] | d_loss: 0.5763 | g_loss: 2.5940
# Epoch [   29/  100] | d_loss: 0.6842 | g_loss: 2.2064
# Epoch [   30/  100] | d_loss: 0.5569 | g_loss: 1.6970
# Epoch [   30/  100] | d_loss: 0.5476 | g_loss: 2.0079
# Epoch [   30/  100] | d_loss: 0.5727 | g_loss: 2.7245
# Epoch [   30/  100] | d_loss: 0.5402 | g_loss: 2.7455
# Epoch [   31/  100] | d_loss: 0.5567 | g_loss: 2.8892
# Epoch [   31/  100] | d_loss: 0.5638 | g_loss: 1.7773
# Epoch [   31/  100] | d_loss: 0.7054 | g_loss: 1.8607
# Epoch [   31/  100] | d_loss: 0.5711 | g_loss: 2.8679
# Epoch [   32/  100] | d_loss: 0.4903 | g_loss: 2.4157
# Epoch [   32/  100] | d_loss: 0.4966 | g_loss: 3.8385
# Epoch [   32/  100] | d_loss: 0.7680 | g_loss: 1.8739
# Epoch [   32/  100] | d_loss: 0.4571 | g_loss: 2.9244
# Epoch [   33/  100] | d_loss: 0.4613 | g_loss: 3.3641
# Epoch [   33/  100] | d_loss: 0.5633 | g_loss: 2.0243
# Epoch [   33/  100] | d_loss: 0.5814 | g_loss: 2.3117
# Epoch [   33/  100] | d_loss: 0.5526 | g_loss: 2.5093
# Epoch [   34/  100] | d_loss: 0.5971 | g_loss: 1.7941
# Epoch [   34/  100] | d_loss: 0.8050 | g_loss: 1.9518
# Epoch [   34/  100] | d_loss: 0.4817 | g_loss: 2.3184
# Epoch [   34/  100] | d_loss: 0.5543 | g_loss: 2.0924
# Epoch [   35/  100] | d_loss: 0.7053 | g_loss: 3.5119
# Epoch [   35/  100] | d_loss: 0.5215 | g_loss: 2.4678
# Epoch [   35/  100] | d_loss: 0.4691 | g_loss: 2.0744
# Epoch [   35/  100] | d_loss: 0.5781 | g_loss: 3.0764
# Epoch [   36/  100] | d_loss: 0.4747 | g_loss: 3.3284
# Epoch [   36/  100] | d_loss: 0.4757 | g_loss: 2.4865
# Epoch [   36/  100] | d_loss: 0.5722 | g_loss: 2.9310
# Epoch [   36/  100] | d_loss: 0.5100 | g_loss: 2.6304
# Epoch [   37/  100] | d_loss: 0.4861 | g_loss: 2.8348
# Epoch [   37/  100] | d_loss: 0.6344 | g_loss: 1.8381
# Epoch [   37/  100] | d_loss: 0.4696 | g_loss: 2.7983
# Epoch [   37/  100] | d_loss: 0.5671 | g_loss: 2.7301
# Epoch [   38/  100] | d_loss: 0.5620 | g_loss: 1.9782
# Epoch [   38/  100] | d_loss: 1.2999 | g_loss: 1.4960
# Epoch [   38/  100] | d_loss: 0.5971 | g_loss: 2.2296
# Epoch [   38/  100] | d_loss: 0.5006 | g_loss: 3.3469
# Epoch [   39/  100] | d_loss: 0.4972 | g_loss: 2.3038
# Epoch [   39/  100] | d_loss: 0.4662 | g_loss: 2.8422
# Epoch [   39/  100] | d_loss: 0.5048 | g_loss: 2.8556
# Epoch [   39/  100] | d_loss: 0.4769 | g_loss: 3.0570
# Epoch [   40/  100] | d_loss: 0.4872 | g_loss: 2.9800
# Epoch [   40/  100] | d_loss: 0.4882 | g_loss: 2.7420
# Epoch [   40/  100] | d_loss: 0.5824 | g_loss: 3.0153
# Epoch [   40/  100] | d_loss: 0.4825 | g_loss: 2.6285
# Epoch [   41/  100] | d_loss: 0.4524 | g_loss: 3.0980
# Epoch [   41/  100] | d_loss: 0.4489 | g_loss: 2.4440
# Epoch [   41/  100] | d_loss: 0.6161 | g_loss: 2.3194
# Epoch [   41/  100] | d_loss: 0.4672 | g_loss: 2.9323
# Epoch [   42/  100] | d_loss: 0.4534 | g_loss: 3.2478
# Epoch [   42/  100] | d_loss: 0.4587 | g_loss: 3.1894
# Epoch [   42/  100] | d_loss: 0.4708 | g_loss: 2.9602
# Epoch [   42/  100] | d_loss: 0.4499 | g_loss: 2.9357
# Epoch [   43/  100] | d_loss: 0.7739 | g_loss: 1.6026
# Epoch [   43/  100] | d_loss: 0.5273 | g_loss: 3.0255
# Epoch [   43/  100] | d_loss: 0.5575 | g_loss: 3.1301
# Epoch [   43/  100] | d_loss: 0.5832 | g_loss: 2.9890
# Epoch [   44/  100] | d_loss: 0.4714 | g_loss: 3.2889
# Epoch [   44/  100] | d_loss: 0.5347 | g_loss: 2.2890
# Epoch [   44/  100] | d_loss: 0.6833 | g_loss: 2.7650
# Epoch [   44/  100] | d_loss: 0.5610 | g_loss: 3.2731
# Epoch [   45/  100] | d_loss: 0.9671 | g_loss: 4.3426
# Epoch [   45/  100] | d_loss: 0.8640 | g_loss: 1.4697
# Epoch [   45/  100] | d_loss: 0.5189 | g_loss: 2.9224
# Epoch [   45/  100] | d_loss: 0.5241 | g_loss: 2.4029
# Epoch [   46/  100] | d_loss: 0.5745 | g_loss: 3.1271
# Epoch [   46/  100] | d_loss: 0.4035 | g_loss: 3.6215
# Epoch [   46/  100] | d_loss: 0.5504 | g_loss: 3.7024
# Epoch [   46/  100] | d_loss: 0.4898 | g_loss: 2.5373
# Epoch [   47/  100] | d_loss: 0.4335 | g_loss: 3.1114
# Epoch [   47/  100] | d_loss: 0.4145 | g_loss: 2.7241
# Epoch [   47/  100] | d_loss: 0.7596 | g_loss: 1.7656
# Epoch [   47/  100] | d_loss: 0.5091 | g_loss: 1.6136
# Epoch [   48/  100] | d_loss: 0.6749 | g_loss: 3.2292
# Epoch [   48/  100] | d_loss: 0.4393 | g_loss: 2.5637
# Epoch [   48/  100] | d_loss: 0.4646 | g_loss: 3.0107
# Epoch [   48/  100] | d_loss: 0.5233 | g_loss: 2.3444
# Epoch [   49/  100] | d_loss: 0.8411 | g_loss: 2.9365
# Epoch [   49/  100] | d_loss: 0.5028 | g_loss: 2.8059
# Epoch [   49/  100] | d_loss: 0.4713 | g_loss: 1.9871
# Epoch [   49/  100] | d_loss: 0.6902 | g_loss: 1.3059
# Epoch [   50/  100] | d_loss: 0.4658 | g_loss: 2.8428
# Epoch [   50/  100] | d_loss: 0.5356 | g_loss: 2.6365
# Epoch [   50/  100] | d_loss: 0.6516 | g_loss: 2.1987
# Epoch [   50/  100] | d_loss: 0.4918 | g_loss: 2.7127
# Epoch [   51/  100] | d_loss: 0.5309 | g_loss: 2.8750
# Epoch [   51/  100] | d_loss: 0.4509 | g_loss: 2.4505
# Epoch [   51/  100] | d_loss: 0.5533 | g_loss: 3.6371
# Epoch [   51/  100] | d_loss: 0.5653 | g_loss: 3.0314
# Epoch [   52/  100] | d_loss: 0.6424 | g_loss: 3.2228
# Epoch [   52/  100] | d_loss: 0.6089 | g_loss: 4.4130
# Epoch [   52/  100] | d_loss: 0.4511 | g_loss: 2.7162
# Epoch [   52/  100] | d_loss: 0.6816 | g_loss: 2.0053
# Epoch [   53/  100] | d_loss: 0.4447 | g_loss: 2.7718
# Epoch [   53/  100] | d_loss: 0.5093 | g_loss: 3.7258
# Epoch [   53/  100] | d_loss: 0.4461 | g_loss: 2.8272
# Epoch [   53/  100] | d_loss: 0.4920 | g_loss: 2.2374
# Epoch [   54/  100] | d_loss: 2.0902 | g_loss: 5.4561
# Epoch [   54/  100] | d_loss: 0.6033 | g_loss: 2.8411
# Epoch [   54/  100] | d_loss: 0.4884 | g_loss: 2.8932
# Epoch [   54/  100] | d_loss: 0.5471 | g_loss: 1.4522
# Epoch [   55/  100] | d_loss: 0.5106 | g_loss: 3.6534
# Epoch [   55/  100] | d_loss: 0.4400 | g_loss: 2.8638
# Epoch [   55/  100] | d_loss: 0.4262 | g_loss: 2.6687
# Epoch [   55/  100] | d_loss: 0.5265 | g_loss: 2.4927
# Epoch [   56/  100] | d_loss: 0.4810 | g_loss: 2.3350
# Epoch [   56/  100] | d_loss: 0.4514 | g_loss: 1.8765
# Epoch [   56/  100] | d_loss: 0.6571 | g_loss: 1.7578
# Epoch [   56/  100] | d_loss: 0.5850 | g_loss: 2.4642
# Epoch [   57/  100] | d_loss: 0.6486 | g_loss: 2.1236
# Epoch [   57/  100] | d_loss: 0.7752 | g_loss: 2.8820
# Epoch [   57/  100] | d_loss: 0.4686 | g_loss: 2.7699
# Epoch [   57/  100] | d_loss: 0.8336 | g_loss: 1.1221
# Epoch [   58/  100] | d_loss: 0.5051 | g_loss: 2.2916
# Epoch [   58/  100] | d_loss: 0.4442 | g_loss: 2.6171
# Epoch [   58/  100] | d_loss: 0.5665 | g_loss: 3.2278
# Epoch [   58/  100] | d_loss: 0.4704 | g_loss: 2.2318
# Epoch [   59/  100] | d_loss: 0.4607 | g_loss: 2.4550
# Epoch [   59/  100] | d_loss: 0.7052 | g_loss: 3.3462
# Epoch [   59/  100] | d_loss: 0.4659 | g_loss: 2.6482
# Epoch [   59/  100] | d_loss: 0.7258 | g_loss: 1.4699
# Epoch [   60/  100] | d_loss: 0.5330 | g_loss: 3.0193
# Epoch [   60/  100] | d_loss: 0.4499 | g_loss: 2.3613
# Epoch [   60/  100] | d_loss: 0.4081 | g_loss: 3.5914
# Epoch [   60/  100] | d_loss: 0.5139 | g_loss: 2.4537
# Epoch [   61/  100] | d_loss: 0.4979 | g_loss: 2.7345
# Epoch [   61/  100] | d_loss: 0.4500 | g_loss: 3.0854
# Epoch [   61/  100] | d_loss: 0.4603 | g_loss: 4.0348
# Epoch [   61/  100] | d_loss: 0.4206 | g_loss: 2.8652
# Epoch [   62/  100] | d_loss: 0.4144 | g_loss: 2.6442
# Epoch [   62/  100] | d_loss: 0.6491 | g_loss: 3.1196
# Epoch [   62/  100] | d_loss: 0.5488 | g_loss: 3.0034
# Epoch [   62/  100] | d_loss: 0.4677 | g_loss: 2.9611
# Epoch [   63/  100] | d_loss: 0.6863 | g_loss: 3.9526
# Epoch [   63/  100] | d_loss: 0.5152 | g_loss: 2.0361
# Epoch [   63/  100] | d_loss: 0.4224 | g_loss: 2.6412
# Epoch [   63/  100] | d_loss: 0.4537 | g_loss: 3.2646
# Epoch [   64/  100] | d_loss: 0.5001 | g_loss: 3.1567
# Epoch [   64/  100] | d_loss: 0.4788 | g_loss: 2.8147
# Epoch [   64/  100] | d_loss: 0.5180 | g_loss: 2.2673
# Epoch [   64/  100] | d_loss: 0.7280 | g_loss: 2.1458
# Epoch [   65/  100] | d_loss: 0.7188 | g_loss: 2.8665
# Epoch [   65/  100] | d_loss: 0.3928 | g_loss: 3.3081
# Epoch [   65/  100] | d_loss: 0.4297 | g_loss: 3.9194
# Epoch [   65/  100] | d_loss: 0.4553 | g_loss: 3.1003
# Epoch [   66/  100] | d_loss: 0.4849 | g_loss: 2.9104
# Epoch [   66/  100] | d_loss: 0.3809 | g_loss: 3.5430
# Epoch [   66/  100] | d_loss: 0.4170 | g_loss: 2.4482
# Epoch [   66/  100] | d_loss: 0.4827 | g_loss: 3.2099
# Epoch [   67/  100] | d_loss: 0.4262 | g_loss: 3.3145
# Epoch [   67/  100] | d_loss: 0.5987 | g_loss: 2.8953
# Epoch [   67/  100] | d_loss: 0.4265 | g_loss: 3.9011
# Epoch [   67/  100] | d_loss: 0.4059 | g_loss: 3.2218
# Epoch [   68/  100] | d_loss: 0.8185 | g_loss: 2.8757
# Epoch [   68/  100] | d_loss: 0.4618 | g_loss: 3.2847
# Epoch [   68/  100] | d_loss: 0.4926 | g_loss: 1.6601
# Epoch [   68/  100] | d_loss: 0.4355 | g_loss: 3.3202
# Epoch [   69/  100] | d_loss: 0.5472 | g_loss: 3.5933
# Epoch [   69/  100] | d_loss: 0.4372 | g_loss: 3.2356
# Epoch [   69/  100] | d_loss: 0.4533 | g_loss: 4.5427
# Epoch [   69/  100] | d_loss: 0.4654 | g_loss: 3.9454
# Epoch [   70/  100] | d_loss: 0.4229 | g_loss: 4.0107
# Epoch [   70/  100] | d_loss: 0.7072 | g_loss: 2.2515
# Epoch [   70/  100] | d_loss: 0.4366 | g_loss: 2.6304
# Epoch [   70/  100] | d_loss: 0.4419 | g_loss: 2.3679
# Epoch [   71/  100] | d_loss: 0.6832 | g_loss: 3.1697
# Epoch [   71/  100] | d_loss: 0.6301 | g_loss: 2.7372
# Epoch [   71/  100] | d_loss: 0.4813 | g_loss: 2.7353
# Epoch [   71/  100] | d_loss: 0.4113 | g_loss: 4.3397
# Epoch [   72/  100] | d_loss: 0.9144 | g_loss: 2.0342
# Epoch [   72/  100] | d_loss: 0.4881 | g_loss: 3.1879
# Epoch [   72/  100] | d_loss: 0.5128 | g_loss: 2.1313
# Epoch [   72/  100] | d_loss: 0.4188 | g_loss: 4.2142
# Epoch [   73/  100] | d_loss: 0.4005 | g_loss: 3.1088
# Epoch [   73/  100] | d_loss: 0.4271 | g_loss: 3.5225
# Epoch [   73/  100] | d_loss: 0.4595 | g_loss: 3.3005
# Epoch [   73/  100] | d_loss: 0.4258 | g_loss: 2.8605
# Epoch [   74/  100] | d_loss: 0.5356 | g_loss: 2.8299
# Epoch [   74/  100] | d_loss: 0.7851 | g_loss: 4.3496
# Epoch [   74/  100] | d_loss: 0.5307 | g_loss: 3.1379
# Epoch [   74/  100] | d_loss: 0.5463 | g_loss: 2.6831
# Epoch [   75/  100] | d_loss: 0.4685 | g_loss: 3.7690
# Epoch [   75/  100] | d_loss: 0.4544 | g_loss: 2.8917
# Epoch [   75/  100] | d_loss: 0.5087 | g_loss: 4.0600
# Epoch [   75/  100] | d_loss: 0.4009 | g_loss: 3.4531
# Epoch [   76/  100] | d_loss: 0.9551 | g_loss: 2.7384
# Epoch [   76/  100] | d_loss: 0.5319 | g_loss: 2.2486
# Epoch [   76/  100] | d_loss: 0.3840 | g_loss: 3.7343
# Epoch [   76/  100] | d_loss: 0.4723 | g_loss: 3.9170
# Epoch [   77/  100] | d_loss: 0.5669 | g_loss: 2.6575
# Epoch [   77/  100] | d_loss: 0.4214 | g_loss: 3.6048
# Epoch [   77/  100] | d_loss: 0.4392 | g_loss: 3.7523
# Epoch [   77/  100] | d_loss: 0.4640 | g_loss: 3.1202
# Epoch [   78/  100] | d_loss: 0.6637 | g_loss: 1.9239
# Epoch [   78/  100] | d_loss: 0.5553 | g_loss: 2.1488
# Epoch [   78/  100] | d_loss: 0.4266 | g_loss: 3.6467
# Epoch [   78/  100] | d_loss: 0.4363 | g_loss: 3.1633
# Epoch [   79/  100] | d_loss: 0.3871 | g_loss: 2.8931
# Epoch [   79/  100] | d_loss: 0.4412 | g_loss: 2.8775
# Epoch [   79/  100] | d_loss: 0.4292 | g_loss: 3.4259
# Epoch [   79/  100] | d_loss: 1.0189 | g_loss: 0.7027
# Epoch [   80/  100] | d_loss: 0.8155 | g_loss: 2.8275
# Epoch [   80/  100] | d_loss: 0.4485 | g_loss: 2.7421
# Epoch [   80/  100] | d_loss: 0.5069 | g_loss: 3.6031
# Epoch [   80/  100] | d_loss: 0.4220 | g_loss: 3.4540
# Epoch [   81/  100] | d_loss: 0.5409 | g_loss: 3.4857
# Epoch [   81/  100] | d_loss: 0.4794 | g_loss: 3.6055
# Epoch [   81/  100] | d_loss: 0.4389 | g_loss: 4.2006
# Epoch [   81/  100] | d_loss: 0.6487 | g_loss: 3.0664
# Epoch [   82/  100] | d_loss: 0.4565 | g_loss: 1.5380
# Epoch [   82/  100] | d_loss: 0.5200 | g_loss: 2.2523
# Epoch [   82/  100] | d_loss: 0.4322 | g_loss: 2.5191
# Epoch [   82/  100] | d_loss: 0.4976 | g_loss: 3.0365
# Epoch [   83/  100] | d_loss: 0.4187 | g_loss: 3.1383
# Epoch [   83/  100] | d_loss: 0.3808 | g_loss: 4.2872
# Epoch [   83/  100] | d_loss: 0.4346 | g_loss: 3.7534
# Epoch [   83/  100] | d_loss: 0.4018 | g_loss: 3.5986
# Epoch [   84/  100] | d_loss: 0.5916 | g_loss: 2.0119
# Epoch [   84/  100] | d_loss: 0.4027 | g_loss: 3.5745
# Epoch [   84/  100] | d_loss: 0.3844 | g_loss: 3.3512
# Epoch [   84/  100] | d_loss: 1.0188 | g_loss: 4.0441
# Epoch [   85/  100] | d_loss: 0.4135 | g_loss: 3.4203
# Epoch [   85/  100] | d_loss: 0.4928 | g_loss: 3.2890
# Epoch [   85/  100] | d_loss: 0.4148 | g_loss: 3.4905
# Epoch [   85/  100] | d_loss: 0.4836 | g_loss: 2.1491
# Epoch [   86/  100] | d_loss: 0.3640 | g_loss: 4.6310
# Epoch [   86/  100] | d_loss: 0.3982 | g_loss: 3.7409
# Epoch [   86/  100] | d_loss: 0.4879 | g_loss: 2.6572
# Epoch [   86/  100] | d_loss: 0.4301 | g_loss: 3.7011
# Epoch [   87/  100] | d_loss: 0.4070 | g_loss: 2.5174
# Epoch [   87/  100] | d_loss: 0.4585 | g_loss: 2.9058
# Epoch [   87/  100] | d_loss: 0.5019 | g_loss: 2.6216
# Epoch [   87/  100] | d_loss: 0.3857 | g_loss: 3.7006
# Epoch [   88/  100] | d_loss: 0.4383 | g_loss: 3.9202
# Epoch [   88/  100] | d_loss: 0.4187 | g_loss: 3.7508
# Epoch [   88/  100] | d_loss: 0.3750 | g_loss: 3.9173
# Epoch [   88/  100] | d_loss: 0.5682 | g_loss: 1.9892
# Epoch [   89/  100] | d_loss: 0.4606 | g_loss: 3.3147
# Epoch [   89/  100] | d_loss: 0.5252 | g_loss: 3.0716
# Epoch [   89/  100] | d_loss: 0.4246 | g_loss: 3.5627
# Epoch [   89/  100] | d_loss: 0.6882 | g_loss: 3.4587
# Epoch [   90/  100] | d_loss: 0.4353 | g_loss: 3.3050
# Epoch [   90/  100] | d_loss: 0.7735 | g_loss: 3.3705
# Epoch [   90/  100] | d_loss: 0.4474 | g_loss: 3.7898
# Epoch [   90/  100] | d_loss: 0.4698 | g_loss: 3.0149
# Epoch [   91/  100] | d_loss: 0.5628 | g_loss: 4.0351
# Epoch [   91/  100] | d_loss: 0.7275 | g_loss: 1.3439
# Epoch [   91/  100] | d_loss: 0.5144 | g_loss: 2.5295
# Epoch [   91/  100] | d_loss: 0.5482 | g_loss: 3.3328
# Epoch [   92/  100] | d_loss: 0.3989 | g_loss: 2.7626
# Epoch [   92/  100] | d_loss: 0.5073 | g_loss: 3.6306
# Epoch [   92/  100] | d_loss: 0.4103 | g_loss: 2.7606
# Epoch [   92/  100] | d_loss: 0.3898 | g_loss: 3.1926
# Epoch [   93/  100] | d_loss: 0.6939 | g_loss: 4.9395
# Epoch [   93/  100] | d_loss: 0.4553 | g_loss: 2.0617
# Epoch [   93/  100] | d_loss: 0.3774 | g_loss: 4.8322
# Epoch [   93/  100] | d_loss: 0.3784 | g_loss: 3.9251
# Epoch [   94/  100] | d_loss: 0.4169 | g_loss: 2.8104
# Epoch [   94/  100] | d_loss: 0.3704 | g_loss: 3.8315
# Epoch [   94/  100] | d_loss: 0.5098 | g_loss: 4.0127
# Epoch [   94/  100] | d_loss: 0.4078 | g_loss: 3.4870
# Epoch [   95/  100] | d_loss: 0.5585 | g_loss: 2.3660
# Epoch [   95/  100] | d_loss: 0.4519 | g_loss: 3.7311
# Epoch [   95/  100] | d_loss: 0.4512 | g_loss: 3.4539
# Epoch [   95/  100] | d_loss: 0.5422 | g_loss: 2.5543
# Epoch [   96/  100] | d_loss: 0.4020 | g_loss: 4.0825
# Epoch [   96/  100] | d_loss: 0.4180 | g_loss: 3.3817
# Epoch [   96/  100] | d_loss: 0.3956 | g_loss: 3.5253
# Epoch [   96/  100] | d_loss: 0.4244 | g_loss: 3.7218
# Epoch [   97/  100] | d_loss: 0.4891 | g_loss: 3.1914
# Epoch [   97/  100] | d_loss: 0.4721 | g_loss: 2.6934
# Epoch [   97/  100] | d_loss: 0.3786 | g_loss: 3.5590
# Epoch [   97/  100] | d_loss: 0.4162 | g_loss: 3.6613
# Epoch [   98/  100] | d_loss: 0.3863 | g_loss: 5.0252
# Epoch [   98/  100] | d_loss: 0.4036 | g_loss: 4.0716
# Epoch [   98/  100] | d_loss: 0.4460 | g_loss: 4.0034
# Epoch [   98/  100] | d_loss: 0.3918 | g_loss: 3.5649
# Epoch [   99/  100] | d_loss: 0.4805 | g_loss: 3.8551
# Epoch [   99/  100] | d_loss: 0.5567 | g_loss: 4.1475

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(1, samples)

# %%
_ = view_samples(5, samples)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
